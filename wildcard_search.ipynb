# %% [markdown]
# Her har du en kommando for å lete etter stavelsesvarianter med jokertegn. Dupliser cellen som inneholder eksempelsøket, og forsøk deg frem med forskjellige parametre, eller søk fra samme celle.
#
# Med kommandoen kan du også søke etter sammensetninger med et gitt prefiks, noe som vil la seg behandle med hyperleksemer etterhvert. Gi beskjed om det er noe du lurer på.

# %%
import pandas as pd
import requests

# %%
def wildcardsearch(params = {'word': '', 'freq_lim':50, 'limit':50, 'factor':2}):
    res = requests.get('https://api.nb.no/ngram/wildcards', params = params)
    if res.status_code == 200:
        result = res.json()
    else:
        result = {'status':'feil'}
    resultat = pd.DataFrame.from_dict(result, orient='index')
    if not(resultat.empty):
        resultat.columns = [params['word']]
    return resultat

def sorted_wildcardsearch(params):
    res = wildcardsearch(params)
    if not res.empty:
        res = res.sort_values(by=params['word'], ascending=False)
    return res

# %% [markdown]
# ### Legg inn ordet det søkes etter med * for åpne plasser.
#
# Sånn sett er det et vanlig søk med * som jokertegn. Parameteret factor bestemmer størrelsen på søket, og vil være det som gir en slags Levenshtein-effekt. Hvis du ønsker å se på sammensetninger økes factor til å få med det. Det blir feil om jokertegnet står først, så søket må startes med en eller flere bokstaver, jo fler bokstaver i starten, desto raskere går søket!

# %%
sorted_wildcardsearch(
    {
        'word': 'xtårtyi',   # her legges selve søkeordet inn
        'factor':10,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50, # sett begrensninger på frekvensen, minimumsverdi
        'limit':50    # begrensning på antall treff
        
    })
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sorted_wildcardsearch(
    {
        'word': 'kj*lig*',   # her legges selve søkeordet inn
        'factor':5,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
#               kj*lig*
# kjærlighet    1148166
# kjærligheten   316328
# kjølig         271474
# kjedelig       215617
# kjærlig        163202
# kjølige        130649
# kjedelige       81876
# kjærlige        63445
# kjærlighed      42363
# kjøligere       31364
# kjødelige       20963
# kjærlighets     20626
# kjærlighet.     14107
# kjærlighet,     13653
# kjødelig        10813
# kjønnslig       10690
# kjennelig       10408
# kjedsommelig    10379
# kjølighet        8476
# kjendelig        8297
# kjærligheden     6874
# kjedeligste      5618
# kjønnslige       5514
# kjærligt         5423
# kjcerlig         5106
# kjedeligt        5077
# kjærligste       5002
# kjedeligere      4570
# kjennelige       4281
# kjcerlighed      4137
# ...               ...
# kjempebillig      147
# kjærlighet,»      145
# kjpdelige         139
# kjeilige          136
# kjempefarlig      134
# kjærligh          133
# kjærlighei        132
# kjserligliet      131
# kjærliget         130
# ...

# %% [markdown]
# sorted_wildcardsearch(
#     {
#         'word': 'kj*lig*t',   # her legges selve søkeordet inn
#         'factor':3,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
#         'freq_lim':50, # sett begrensninger på frekvensen, minimumsverdi
#         'limit':200    # begrensning på antall treff
#
#     })

# %%
sorted_wildcardsearch(
    {
        'word': 'ligcg*ld*g',   # her legges selve søkeordet inn
        'factor':1,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':2, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
#             ligcg*ld*g
# ligcgyldig         259
# ligcgvldig           7
# ligcgpldig           4

# %%
sorted_wildcardsearch(
    {
        'word': 'B*gr*b',   # her legges selve søkeordet inn
        'factor':0,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':1, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
#         B*gr*b
# Begreb   49991
# Begrcb     650
# Bcgreb     486
# Bcgrcb     237
# BEGREB     121
# Begrib      95
# Begrab      50
# Begréb      22
# Bsgreb      17
# Begræb      16
# Begrob      15
# Brgreb      14
# Begrsb      12
# Begrrb      11
# BpGrB       10
# Bogreb       8
# Bégreb       8
# BeGREB       6
# BGrgeB       6
# Begrlb       6
# Bagreb       6
# Begrb        4
# BGrg6B       4
# BegreB       4
# BagreB       4
# Bigreb       4
# Bcgrob       3
# Btgreb       3
# BAKGRB       3
# Brgrcb       3
# Bkgreb       3
# Bigrib       3
# BigrB        3
# Bgrb         3
# BMGreB       3
# Bcgrab       3
# BLYGRB       2
# BcgrcB       2
# BÉGREB       2
# Begr.b       2
# Bsgrsb       2
# BcgreB       2
# Brgrrb       2
# BegrcB       2
# BpgruB       2
# Bgreb        2
# BLSGRB       2
# B.greb       2
# BjGreB       2
# BNGreB       2
# Begrtb       2
# B-greb       2

# %%
sorted_wildcardsearch(
    {
        'word': 'Emancipationsistinde',   # her legges selve søkeordet inn
        'factor':3,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':3, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sorted_wildcardsearch(
    {
        'word': 'Slav*t*l*and',   # her legges selve søkeordet inn
        'factor':1,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':2, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
#                Slav*t*l*and
# Slavetilstand            15

# %%
sorted_wildcardsearch(
    {
        'word': 'L*s*rind*',   # her legges selve søkeordet inn
        'factor':2,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':2, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
#              L*s*rind*
# Læserinder         221
# Læserinde          169
# Lceserinde          60
# Lceserinder         50
# Læserinden          25
# Leserinder          20
# Livserindr          19
# Lundsgrinda         17
# Leserinde           15
# Læserinders         15
# Lcrserinde          15
# Lastgrind           13
# Lcrserinder         12
# Lceserinden          9
# Laserinder           8
# Lofsgrinden          6
# Llsterinde           6
# Løvåsgrinda          6
# LSrinde              5
# Læserindel           5
# Læserindes           5
# Læserinder,          5
# Laserinde            5
# Lysegrind            5
# Loeserinde           5
# Loeserinder          4
# Llskerinde           4
# LIVSERIND            4
# Lceserinde!          3
# Lastgrinden          3
# Lillsøgrind          3
# Lastegrind           3
# Lceserindes          3
# Landskrinda          3
# LUNDSGRINDA          3
# Lesbierinde          3

# %%
sorted_wildcardsearch(
    {
        'word': 'Vanr*ke',   # her legges selve søkeordet inn
        'factor':2,     # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50, # sett begrensninger på frekvensen, minimumsverdi
        'limit':200    # begrensning på antall treff
        
    })
# Out:
# Empty DataFrame
# Columns: []
# Index: []
